# %% [raw]
# ---
# description: I came to the realization that knowledge of AI along isn't that useful
#   unless you can deploy it the public. Hence my interest into web development.
# output-file: web_development.html
# skip_exec: true
# skip_showdoc: true
# title: Adventure into Web and App development
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Web Development

# %% [markdown]
# [https://bthek1.github.io/webdevelopment_doc/](https://bthek1.github.io/webdevelopment_doc/)
