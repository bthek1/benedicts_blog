# %% [markdown]
# ---
# title: "Adventure into Web and App development"
# description: "I came to the realization that knowledge of AI along isn't that useful unless you can deploy it the public. Hence my interest into web development."
# author: "Benedict Thekkel"
# date: "26/04/2024"
# skip_showdoc: true
# skip_exec: true
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Web Development
#
# > [https://bthek1.github.io/webdevelopment_doc/](https://bthek1.github.io/webdevelopment_doc/)

# %% [markdown]
# Web Developement contains information many of servers application I have used untill now aswell as database and front-end applications. There include:

# %% [markdown]
# Back-end
# - Influx
# - Django
# - Nginx
# - Docker
# - Prefect
#
# Front-end
# - Streamlit
# - Gradio
# - Flutter
# - React
# - React-Naive
