# %% [raw]
# ---
# description: Future Map
# output-file: future_map.html
# skip_exec: true
# skip_showdoc: true
# title: Future Map
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from graphviz import Digraph

# %%
import graphviz

g = graphviz.Graph('G', filename='process.gv', engine = 'dot')

g.edge('phosaver', 'flutter')
g.edge('ML', '3D vision')

g.edge('3D vision', 'APP')
g.edge('flutter', 'APP')

g.edge('Drone', 'Business')


g.render( format='svg', cleanup=False)

g
