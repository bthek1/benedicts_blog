# %% [markdown]
# ---
# title: "Exploring Machine Learning"
# description: "I've developed two libraries to delve into machine learning techniques. The ML repo delves into various methods, while MLtools provide in-depth exploration of commonly used libraries that assist in ML development, such as matplotlib, numpy, pandas, scipy, and more."
# date: "26/04/2024"
# skip_showdoc: true
# skip_exec: true
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Machine Learning Techniques
#
# > [https://bthek1.github.io/ML/](https://bthek1.github.io/ML/)

# %% [markdown]
# The ML repo contains example code of most of the popular ML techniques. Created to be a useful quick reference quide for ML developement. Techniques ranging from:
# - KNN
# - Decision Tree
# - Linear Regression
# - Logistic Regression
# - L1 and L2 Regularication
# - Ensemble Methods
# - Naive Bayes
# - Supper Vector Regression (SVR)
# - Random Forest
# - Principal Component Analysis (PCA)
# - CNN

# %% [markdown]
# ## Helpful tools and Libraries for ML
#
# > [https://bthek1.github.io/MLtools/](https://bthek1.github.io/MLtools/)

# %% [markdown]
# ML tools repo contain the breakdown of often used python libraries in conjuction with ML development. Created as a quick reference when trying to remember particular functions. The libraries include:\
# - Matplotlib
# - Numpy
# - Scipy
# - Pandas
# - Pivot Tables
# - Pytube
# - Mito
# - Altair
# - Tqdm
# - Ipywidget
# - Tmux
# - breakdown of Python class and design structures
