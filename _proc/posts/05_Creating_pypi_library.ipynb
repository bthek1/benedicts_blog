# %% [raw]
# ---
# description: I have been using nbdev, to create these webpages from github repos.
#   But the primary role of nbdev is to create python libraries to be put into conda
#   and pip. I have created a python library called NbdevAuto
# output-file: creating_pypi_library.html
# skip_exec: true
# skip_showdoc: true
# title: Creating Pypi Library
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## NbdevAuto

# %% [markdown]
# [https://bthek1.github.io/nbdevAuto/functions.html](https://bthek1.github.io/nbdevAuto/functions.html)
