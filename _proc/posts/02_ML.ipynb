# %% [raw]
# ---
# description: Covering all major concepts in Machine Learning
# output-file: ml.html
# title: ML Course
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/bthek1/benedicts_blog/blob/main/benedicts_blog/fastAI.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()
