# %% [raw]
# ---
# description: As part of my intership, I had to develop models to predict electricity
#   usage for a electricity monitoring company.
# output-file: time_series_analysis.html
# skip_exec: true
# skip_showdoc: true
# title: Building, testing and Deploying Time-Series ML models
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# [https://bthek1.github.io/TimeSeriesML/](https://bthek1.github.io/TimeSeriesML/)
