# %% [markdown]
# ---
# title: "Benedicts Blog"
# listing:
#   id: sample-listings
#   contents:
#     posts
#   sort: "date desc"
#   type: default
#   sort-ui: true
#   filter-ui: true
#   field-display-names:
#     name: "Name"
#     custom-field: "Custom"
#   field-types:
#     custom-date: date
#     custom-number: number
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ::: {#sample-listings}
#
# :::
