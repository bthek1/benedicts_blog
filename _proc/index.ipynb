# %% [markdown]
# ---
# title: "Benedicts Blog"
# listing:
#   id: sample-listings
#   contents: posts
#   sort: "date desc"
#   type: default
#   categories: true
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
